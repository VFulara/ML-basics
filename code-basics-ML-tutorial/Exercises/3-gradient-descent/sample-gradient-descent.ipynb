# %% [markdown]
# <a href="https://colab.research.google.com/github/VFulara/ML-basics/blob/main/code-basics-ML-tutorial/Exercises/3-gradient-descent/sample-gradient-descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

def gradient_descent(x,y):

  learning_rate = .04
  m = 0
  b = 0
  n = len(x)

  for i in range(500):
    yPredicted = (m*x) + b
    cost = (1/n) * sum([val**2 for val in (y-yPredicted)])

    md = -(2/n) * sum (x * (y - yPredicted))
    mb = -(2/n) * sum (y - yPredicted)

    m = m - learning_rate * md
    b = b - learning_rate * mb

    print("s.no {}:  m {}, b {}, cost {}".format(i, m, b, cost))





x = np.array([1,2,3,4,5])
y = np.array([5,6,7,8,9])

gradient_descent(x,y)
# Out:
# s.no 0:  m 1.84, b 0.56, cost 51.0
# s.no 1:  m 1.9264, b 0.6336, cost 2.2575999999999996
# s.no 2:  m 1.919104, b 0.6805760000000001, cost 2.0612377600000005
# s.no 3:  m 1.90695424, b 0.72554496, cost 2.0054742261760006
# s.no 4:  m 1.8947037184, b 0.7698323456, cost 1.9515964436709383
# s.no 5:  m 1.882604683264, b 0.813516865536, cost 1.8991671877561325
# s.no 6:  m 1.8706685142630401, b 0.85661039230976, cost 1.848146436620462
# s.no 7:  m 1.8588937275572224, b 0.8991211175018495, cost 1.7984963478888571
# s.no 8:  m 1.8472781791064228, b 0.9410569334879682, cost 1.7501800989776566
# s.no 9:  m 1.8358197174556585, b 0.9824256158233893, cost 1.7031618565436937
# s.no 10:  m 1.8245162182970656, b 1.02323483436816, cost 1.6574067498995118
# s.no 11:  m 1.8133655859472895, b 1.0634921552274115, cost 1.6128808451517767
# s.no 12:  m 1.802365753059096, b 1.103205042181869, cost 1.5695511200344943
# s.no 13:  m 1.7915146802434427, b 1.1423808580731365, cost 1.5273854394183184
# ...
